# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/GB_Intro_Further_Mathematics/blob/lesson1/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(0, 10, 21)


plt.plot(x, np.cos(x), marker = 'o')
k = 0.5
plt.plot(x, np.cos(k * x), marker = 'o')
print(x)
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10. ]
